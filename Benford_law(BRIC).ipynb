# %%
import benford as bf
import pandas as pd
sp=pd.read_csv('BricSecAll.csv')
sp
# Out:
#      country        date sector    value20    value21  Unnamed: 5 country.1  \
# 0     Brazil    1/1/2020  Power   0.302034   0.297697         NaN    Brazil
# 1      China    1/1/2020  Power  16.502400  16.342900         NaN     China
# 2      India    1/1/2020  Power   3.294040   3.486970         NaN     India
# 3     Russia    1/1/2020  Power   2.581640   2.313780         NaN    Russia
# 4     Brazil    1/2/2020  Power   0.313837   0.305347         NaN    Brazil
# ...      ...         ...    ...        ...        ...         ...       ...
# 1459  Russia  12/30/2020  Power   2.608050   2.686140         NaN    Russia
# 1460  Brazil  12/31/2020  Power   0.339833        NaN         NaN    Brazil
# 1461   China  12/31/2020  Power  16.674600        NaN         NaN     China
# 1462   India  12/31/2020  Power   3.522990        NaN         NaN     India
# 1463  Russia  12/31/2020  Power   2.466490        NaN         NaN    Russia
#
# ...

# %%
#BRIC(Power)  first digit project 2020
f1d=bf.first_digits(sp.value20,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value20,test=1,decimals=8) #mad for first digit
print('mad1:',mad1)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1             796.0  0.543716  0.301030
# 2             282.0  0.192623  0.176091
# 3             360.0  0.245902  0.124939
# 4               0.0  0.000000  0.096910
# 5               0.0  0.000000  0.079181
# 6               0.0  0.000000  0.066947
# 7               0.0  0.000000  0.057992
# 8               2.0  0.001366  0.051153
# 9              24.0  0.016393  0.045757
# mad1: 0.08448454351789057

# %%
#BRIC(Power)  second digit project 2020
sd=bf.second_digit(sp.value20,decimals=8) #for the 2nd digits
print(sd)
mad22=bf.mad(sp.value20,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           111  0.075820  0.119679
# 1           223  0.152322  0.113890
# 2           194  0.132514  0.108821
# 3           177  0.120902  0.104330
# 4           167  0.114071  0.100308
# 5           177  0.120902  0.096677
# 6           127  0.086749  0.093375
# 7           122  0.083333  0.090352
# 8            71  0.048497  0.087570
# 9            95  0.064891  0.084997
# MAD: 0.023336756359947038

# %%
#BRIC(Power)  two digit project 2020
f2d=bf.first_digits(sp.value20,digs=2,decimals=8) #for the first 2 digits
mad2=bf.mad(sp.value20,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
# MAD: 0.009909315759626402

# %%
#BRIC(Power)  first digit project 2021
f1d=bf.first_digits(sp.value21,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value21,test=1,decimals=8) #mad for first digit
print('mad1:',mad1)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1             550.0  0.376712  0.301030
# 2             410.0  0.280822  0.176091
# 3             460.0  0.315068  0.124939
# 4              40.0  0.027397  0.096910
# 5               0.0  0.000000  0.079181
# 6               0.0  0.000000  0.066947
# 7               0.0  0.000000  0.057992
# 8               0.0  0.000000  0.051153
# 9               0.0  0.000000  0.045757
# mad1: 0.08234283297734779

# %%
#BRIC(Power)  second digit project 2021
mad22=bf.mad(sp.value21,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# MAD: 0.020135178860102892

# %%
#BRIC(Power)  two digit project 2021
mad2=bf.mad(sp.value21,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# MAD: 0.009712720167488323

# %%
#BRIC(Industry)  first digit project 2020
f1d=bf.first_digits(sp.value20a,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value20a,test=1,decimals=8) #mad for first digit
print('mad1:',mad1)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               511  0.349044  0.301030
# 2               235  0.160519  0.176091
# 3               204  0.139344  0.124939
# 4                61  0.041667  0.096910
# 5                18  0.012295  0.079181
# 6                88  0.060109  0.066947
# 7               168  0.114754  0.057992
# 8               128  0.087432  0.051153
# 9                51  0.034836  0.045757
# mad1: 0.034546793065434254

# %%
#BRIC(Industry)  second digit project 2020
sd=bf.second_digit(sp.value20a,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value20a,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           170  0.116120  0.119679
# 1           202  0.137978  0.113890
# 2           282  0.192623  0.108821
# 3           178  0.121585  0.104330
# 4            93  0.063525  0.100308
# 5            91  0.062158  0.096677
# 6            96  0.065574  0.093375
# 7           125  0.085383  0.090352
# 8           104  0.071038  0.087570
# 9           123  0.084016  0.084997
# MAD: 0.025028925941140513

# %%
#BRIC(Industry) two digits 2020
f2d=bf.first_digits(sp.value20a,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value20a,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10             40.0  0.027322  0.041393
# 11             52.0  0.035519  0.037789
# 12            158.0  0.107923  0.034762
# 13             77.0  0.052596  0.032185
# 14             13.0  0.008880  0.029963
# ...             ...       ...       ...
# 95              2.0  0.001366  0.004548
# 96              9.0  0.006148  0.004501
# 97              6.0  0.004098  0.004454
# 98              9.0  0.006148  0.004409
# 99              6.0  0.004098  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.006554104694121067

# %%
#BRIC(Industry)  first digit project 2021
f1d=bf.first_digits(sp.value21a,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value21a,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               506  0.346575  0.301030
# 2               303  0.207534  0.176091
# 3               198  0.135616  0.124939
# 4                90  0.061644  0.096910
# 5                 6  0.004110  0.079181
# 6                29  0.019863  0.066947
# 7               112  0.076712  0.057992
# 8               156  0.106849  0.051153
# 9                60  0.041096  0.045757
# mad: 0.03601849121774363

# %%
#BRIC(Industry)  second digit project 2021
sd=bf.second_digit(sp.value21a,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value21a,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           244  0.167123  0.119679
# 1           267  0.182877  0.113890
# 2           200  0.136986  0.108821
# 3           148  0.101370  0.104330
# 4           113  0.077397  0.100308
# 5            76  0.052055  0.096677
# 6            87  0.059589  0.093375
# 7            90  0.061644  0.090352
# 8           106  0.072603  0.087570
# 9           129  0.088356  0.084997
# MAD: 0.029590848537157384

# %%
#BRIC(Industry) two digits 2021
f2d=bf.first_digits(sp.value21a,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value21a,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10             88.0  0.060274  0.041393
# 11            123.0  0.084247  0.037789
# 12             77.0  0.052740  0.034762
# 13             75.0  0.051370  0.032185
# 14             15.0  0.010274  0.029963
# ...             ...       ...       ...
# 95              5.0  0.003425  0.004548
# 96              6.0  0.004110  0.004501
# 97              5.0  0.003425  0.004454
# 98              5.0  0.003425  0.004409
# 99              4.0  0.002740  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.008052801392813362

# %%
#BRIC(Domestic Aviat.)  first digit project 2020
f1d=bf.first_digits(sp.value20b,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value20b,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               556  0.379781  0.301030
# 2               215  0.146858  0.176091
# 3               247  0.168716  0.124939
# 4               149  0.101776  0.096910
# 5               110  0.075137  0.079181
# 6                73  0.049863  0.066947
# 7                55  0.037568  0.057992
# 8                34  0.023224  0.051153
# 9                25  0.017077  0.045757
# mad: 0.02830988416963962

# %%
#BRIC(Domestic Aviat.)  second digit project 2020
sd=bf.second_digit(sp.value20b,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value20b,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           152  0.103825  0.119679
# 1           198  0.135246  0.113890
# 2           158  0.107923  0.108821
# 3           142  0.096995  0.104330
# 4           137  0.093579  0.100308
# 5           133  0.090847  0.096677
# 6           100  0.068306  0.093375
# 7           129  0.088115  0.090352
# 8           188  0.128415  0.087570
# 9           127  0.086749  0.084997
# MAD: 0.01279046540429272

# %%
#BRIC(Industry) two digits 2020
f2d=bf.first_digits(sp.value20b,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value20b,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10             39.0  0.026639  0.041393
# 11             67.0  0.045765  0.037789
# 12             60.0  0.040984  0.034762
# 13             53.0  0.036202  0.032185
# 14             43.0  0.029372  0.029963
# ...             ...       ...       ...
# 95              3.0  0.002049  0.004548
# 96              1.0  0.000683  0.004501
# 97              1.0  0.000683  0.004454
# 98              2.0  0.001366  0.004409
# 99              3.0  0.002049  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.004546524639942037

# %%
#BRIC(Domestic Aviat.)  first digit project 2021
f1d=bf.first_digits(sp.value21b,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value21b,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               684  0.468493  0.301030
# 2               262  0.179452  0.176091
# 3               131  0.089726  0.124939
# 4               112  0.076712  0.096910
# 5                84  0.057534  0.079181
# 6               125  0.085616  0.066947
# 7                10  0.006849  0.057992
# 8                22  0.015068  0.051153
# 9                30  0.020548  0.045757
# mad: 0.042109688774520176

# %%
#BRIC(Domestic Aviat.)  second digit project 2021
sd=bf.second_digit(sp.value21b,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value21b,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           136  0.093151  0.119679
# 1           119  0.081507  0.113890
# 2           136  0.093151  0.108821
# 3           154  0.105479  0.104330
# 4           138  0.094521  0.100308
# 5           157  0.107534  0.096677
# 6           212  0.145205  0.093375
# 7           135  0.092466  0.090352
# 8           139  0.095205  0.087570
# 9           134  0.091781  0.084997
# MAD: 0.016074061230847446

# %%
#BRIC(Domestic Avait.) two digits 2021
f2d=bf.first_digits(sp.value21b,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value21b,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10             43.0  0.029452  0.041393
# 11             41.0  0.028082  0.037789
# 12             58.0  0.039726  0.034762
# 13             63.0  0.043151  0.032185
# 14             52.0  0.035616  0.029963
# ...             ...       ...       ...
# 95              3.0  0.002055  0.004548
# 96              2.0  0.001370  0.004501
# 97              1.0  0.000685  0.004454
# 98              7.0  0.004795  0.004409
# 99              5.0  0.003425  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.005951733706389941

# %%
#BRIC(International Aviat.)  first digit project 2020
f1d=bf.first_digits(sp.value20c,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value20c,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               463  0.316257  0.301030
# 2               297  0.202869  0.176091
# 3               284  0.193989  0.124939
# 4               114  0.077869  0.096910
# 5                81  0.055328  0.079181
# 6                50  0.034153  0.066947
# 7                63  0.043033  0.057992
# 8                76  0.051913  0.051153
# 9                36  0.024590  0.045757
# mad: 0.024847735250895096

# %%
#BRIC(International Aviat.)  second digit project 2020
sd=bf.second_digit(sp.value20c,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value20c,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           147  0.100410  0.119679
# 1           185  0.126366  0.113890
# 2           167  0.114071  0.108821
# 3           158  0.107923  0.104330
# 4           145  0.099044  0.100308
# 5           114  0.077869  0.096677
# 6           139  0.094945  0.093375
# 7           135  0.092213  0.090352
# 8           142  0.096995  0.087570
# 9           132  0.090164  0.084997
# MAD: 0.0078684604590396

# %%
#BRIC(International Avait.) two digits 2020
f2d=bf.first_digits(sp.value20c,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value20c,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10               48  0.032787  0.041393
# 11               73  0.049863  0.037789
# 12               76  0.051913  0.034762
# 13               66  0.045082  0.032185
# 14               48  0.032787  0.029963
# ...             ...       ...       ...
# 95                4  0.002732  0.004548
# 96                3  0.002049  0.004501
# 97                5  0.003415  0.004454
# 98                4  0.002732  0.004409
# 99                2  0.001366  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.0040277006836360076

# %%
#BRIC(International Aviat.)  first digit project 2021
f1d=bf.first_digits(sp.value21c,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value21c,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               486  0.332877  0.301030
# 2               421  0.288356  0.176091
# 3               196  0.134247  0.124939
# 4                 1  0.000685  0.096910
# 5                17  0.011644  0.079181
# 6                80  0.054795  0.066947
# 7               106  0.072603  0.057992
# 8                94  0.064384  0.051153
# 9                59  0.040411  0.045757
# mad: 0.04028028726036159

# %%
#BRIC(International Aviat.)  second digit project 2021
sd=bf.second_digit(sp.value21c,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value21c,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           145  0.099315  0.119679
# 1           173  0.118493  0.113890
# 2           162  0.110959  0.108821
# 3           163  0.111644  0.104330
# 4           137  0.093836  0.100308
# 5           135  0.092466  0.096677
# 6           147  0.100685  0.093375
# 7           149  0.102055  0.090352
# 8           127  0.086986  0.087570
# 9           122  0.083562  0.084997
# MAD: 0.006613545748338501

# %%
#BRIC(International Avait.) two digits 2021
f2d=bf.first_digits(sp.value21c,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value21c,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10             56.0  0.038356  0.041393
# 11             67.0  0.045890  0.037789
# 12             59.0  0.040411  0.034762
# 13             51.0  0.034932  0.032185
# 14             41.0  0.028082  0.029963
# ...             ...       ...       ...
# 95              6.0  0.004110  0.004548
# 96             12.0  0.008219  0.004501
# 97              5.0  0.003425  0.004454
# 98              4.0  0.002740  0.004409
# 99              5.0  0.003425  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.005610416838513266

# %%
#BRIC(Ground Transpt.)  first digit project 2020
f1d=bf.first_digits(sp.value20d,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value20d,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               101  0.068989  0.301030
# 2               338  0.230874  0.176091
# 3               109  0.074454  0.124939
# 4               265  0.181011  0.096910
# 5                92  0.062842  0.079181
# 6               274  0.187158  0.066947
# 7               103  0.070355  0.057992
# 8               173  0.118169  0.051153
# 9                 9  0.006148  0.045757
# mad: 0.07521683886478

# %%
#BRIC(Ground Transpt.)  second digit project 2020
sd=bf.second_digit(sp.value20d,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value20d,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0            99  0.067623  0.119679
# 1           128  0.087432  0.113890
# 2           126  0.086066  0.108821
# 3           138  0.094262  0.104330
# 4           182  0.124317  0.100308
# 5           206  0.140710  0.096677
# 6           133  0.090847  0.093375
# 7           139  0.094945  0.090352
# 8           193  0.131831  0.087570
# 9           120  0.081967  0.084997
# MAD: 0.023379159554031585

# %%
#BRIC(Domestic Transpt.) two digits 2020
f2d=bf.first_digits(sp.value20d,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value20d,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10             11.0  0.007514  0.041393
# 11             14.0  0.009563  0.037789
# 12              5.0  0.003415  0.034762
# 13              9.0  0.006148  0.032185
# 14              9.0  0.006148  0.029963
# ...             ...       ...       ...
# 95              1.0  0.000683  0.004548
# 96              0.0  0.000000  0.004501
# 97              1.0  0.000683  0.004454
# 98              2.0  0.001366  0.004409
# 99              0.0  0.000000  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.009457171363006762

# %%
#BRIC(Ground Transpt.)  first digit project 2021
f1d=bf.first_digits(sp.value21d,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value21d,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1                14  0.009589  0.301030
# 2               388  0.265753  0.176091
# 3                79  0.054110  0.124939
# 4               306  0.209589  0.096910
# 5                82  0.056164  0.079181
# 6               290  0.198630  0.066947
# 7                84  0.057534  0.057992
# 8               216  0.147945  0.051153
# 9                 1  0.000685  0.045757
# mad: 0.09573716090609909

# %%
#BRIC(Ground Transpt.)  second digit project 2021
sd=bf.second_digit(sp.value21d,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value21d,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0            77  0.052740  0.119679
# 1            71  0.048630  0.113890
# 2           120  0.082192  0.108821
# 3           129  0.088356  0.104330
# 4           189  0.129452  0.100308
# 5           277  0.189726  0.096677
# 6            97  0.066438  0.093375
# 7           112  0.076712  0.090352
# 8           178  0.121918  0.087570
# 9           210  0.143836  0.084997
# MAD: 0.043075732628571894

# %%
#BRIC(Ground Transpt.) two digits 2021
f2d=bf.first_digits(sp.value21d,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value21d,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10              0.0  0.000000  0.041393
# 11              0.0  0.000000  0.037789
# 12              1.0  0.000685  0.034762
# 13              1.0  0.000685  0.032185
# 14              2.0  0.001370  0.029963
# ...             ...       ...       ...
# 95              0.0  0.000000  0.004548
# 96              0.0  0.000000  0.004501
# 97              0.0  0.000000  0.004454
# 98              0.0  0.000000  0.004409
# 99              0.0  0.000000  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.013587922895769157

# %%
#BRIC(Residential)  first digit project 2020
f1d=bf.first_digits(sp.value20e,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value20e,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               492  0.336066  0.301030
# 2               279  0.190574  0.176091
# 3               217  0.148224  0.124939
# 4                72  0.049180  0.096910
# 5                50  0.034153  0.079181
# 6                38  0.025956  0.066947
# 7                54  0.036885  0.057992
# 8                28  0.019126  0.051153
# 9               234  0.159836  0.045757
# mad: 0.04152932703628334

# %%
#BRIC(Residential.)  second digit project 2020
sd=bf.second_digit(sp.value20e,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value20e,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           257  0.175546  0.119679
# 1            70  0.047814  0.113890
# 2            76  0.051913  0.108821
# 3           201  0.137295  0.104330
# 4           120  0.081967  0.100308
# 5           126  0.086066  0.096677
# 6           101  0.068989  0.093375
# 7           127  0.086749  0.090352
# 8           311  0.212432  0.087570
# 9            75  0.051230  0.084997
# MAD: 0.04273886832740284

# %%
#BRIC(Residential) two digits 2020
f2d=bf.first_digits(sp.value20e,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value20e,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1464 registries.
#
# Test performed on 1464 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10            170.0  0.116120  0.041393
# 11             12.0  0.008197  0.037789
# 12             16.0  0.010929  0.034762
# 13            123.0  0.084016  0.032185
# 14             64.0  0.043716  0.029963
# ...             ...       ...       ...
# 95              1.0  0.000683  0.004548
# 96              0.0  0.000000  0.004501
# 97              1.0  0.000683  0.004454
# 98            217.0  0.148224  0.004409
# 99              0.0  0.000000  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.008255262282080117

# %%
#BRIC(Residential)  first digit project 2021
f1d=bf.first_digits(sp.value21e,digs=1,decimals=8) #for the first digit(1-9)
print(f1d)
mad1=bf.mad(sp.value21e,test=1,decimals=8) #mad for first digit
print('mad:',mad1)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 1 after preparation.
#              Counts     Found  Expected
# First_1_Dig
# 1               530  0.363014  0.301030
# 2               253  0.173288  0.176091
# 3               221  0.151370  0.124939
# 4                78  0.053425  0.096910
# 5                41  0.028082  0.079181
# 6                28  0.019178  0.066947
# 7                35  0.023973  0.057992
# 8                34  0.023288  0.051153
# 9               240  0.164384  0.045757
# mad: 0.04600908898993666

# %%
#BRIC(Residential.)  second digit project 2021
sd=bf.second_digit(sp.value21e,decimals=8) #for the 2nd digit
print(sd)
mad22=bf.mad(sp.value21e,test=22,decimals=8) #mad for second digit
print('MAD:',mad22)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#          Counts     Found  Expected
# Sec_Dig
# 0           267  0.182877  0.119679
# 1           110  0.075342  0.113890
# 2            67  0.045890  0.108821
# 3           166  0.113699  0.104330
# 4           127  0.086986  0.100308
# 5            85  0.058219  0.096677
# 6           113  0.077397  0.093375
# 7           111  0.076027  0.090352
# 8           333  0.228082  0.087570
# 9            81  0.055479  0.084997
# MAD: 0.04261573036797474

# %%
#BRIC(Residential) two digits 2021
f2d=bf.first_digits(sp.value21e,digs=2,decimals=8) #for the first 2 digits
print(f2d)
mad2=bf.mad(sp.value21e,test=2,decimals=8) #mad for first two  digits
print('MAD:',mad2)
# Out:
# Initialized sequence with 1460 registries.
#
# Test performed on 1460 registries.
# Discarded 0 records < 10 after preparation.
#              Counts     Found  Expected
# First_2_Dig
# 10            205.0  0.140411  0.041393
# 11             45.0  0.030822  0.037789
# 12             14.0  0.009589  0.034762
# 13            107.0  0.073288  0.032185
# 14             63.0  0.043151  0.029963
# ...             ...       ...       ...
# 95              1.0  0.000685  0.004548
# 96              1.0  0.000685  0.004501
# 97              5.0  0.003425  0.004454
# 98            219.0  0.150000  0.004409
# 99              4.0  0.002740  0.004365
#
# [90 rows x 3 columns]
# MAD: 0.008514939248352877
